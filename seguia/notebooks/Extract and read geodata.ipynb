# %%
from zipfile import ZipFile
import requests
import os

# %%
url = "https://www.inegi.org.mx"
url += "/contenidos/productos/prod_serv/"
url +="contenidos/espanol/bvinegi/productos/"
url +="geografia/marcogeo/889463807469/mg_2020_integrado.zip"
req = requests.get(url)

filename = url.split('/')[-1]
 
with open(filename,'wb') as output_file:
    output_file.write(req.content)
print('Downloading Completed')

# %%
os.mkdir('test_file')
with ZipFile('./mg_2020_integrado.zip', 'r') as zipObj:
    zipObj.extractall('test_file')

# %%
import geopandas as gpd

# %%
test_a = gpd.read_file(
    '../data/external/mg_2020_integrado/conjunto_de_datos/00a.shp'
)

# %%
test_ent = gpd.read_file(
    '../data/external/mg_2020_integrado/conjunto_de_datos/00ent.shp'
)

# %%
test_mun = gpd.read_file(
    '../data/external/mg_2020_integrado/conjunto_de_datos/00mun.shp'
)

# %%
test_l = gpd.read_file(
    '../data/external/mg_2020_integrado/conjunto_de_datos/00l.shp'
)

# %%
test_lpr = gpd.read_file(
    '../data/external/mg_2020_integrado/conjunto_de_datos/00lpr.shp'
)

# %%
test_a
# Out:
#               CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  Ambito  \
# 0      010060001009A      01     006    0001     009A  Urbana
# 1      0100600010244      01     006    0001     0244  Urbana
# 2      0100600010140      01     006    0001     0140  Urbana
# 3      0100600010278      01     006    0001     0278  Urbana
# 4      0100600010070      01     006    0001     0070  Urbana
# ...              ...     ...     ...     ...      ...     ...
# 81446      320560025      32     056    0000     0025   Rural
# 81447      320570145      32     057    0000     0145   Rural
# 81448      32057015A      32     057    0000     015A   Rural
# 81449      320580049      32     058    0000     0049   Rural
# 81450      320580053      32     058    0000     0053   Rural
#
#                                                 geometry
# 0      POLYGON ((2471856.117 1124829.239, 2471859.442...
# 1      POLYGON ((2472405.057 1126442.149, 2472346.028...
# ...

# %%
test_ent
# Out:
#    CVEGEO CVE_ENT                           NOMGEO  \
# 0      01      01                   Aguascalientes
# 1      02      02                  Baja California
# 2      03      03              Baja California Sur
# 3      04      04                         Campeche
# 4      05      05             Coahuila de Zaragoza
# 5      06      06                           Colima
# 6      07      07                          Chiapas
# 7      08      08                        Chihuahua
# 8      09      09                 Ciudad de México
# 9      10      10                          Durango
# 10     11      11                       Guanajuato
# 11     12      12                         Guerrero
# 12     13      13                          Hidalgo
# 13     14      14                          Jalisco
# 14     15      15                           México
# 15     16      16              Michoacán de Ocampo
# 16     17      17                          Morelos
# ...

# %%
test_mun
# Out:
#      CVEGEO CVE_ENT CVE_MUN                 NOMGEO  \
# 0     01001      01     001         Aguascalientes
# 1     01002      01     002               Asientos
# 2     01003      01     003               Calvillo
# 3     01004      01     004                  Cosío
# 4     01005      01     005            Jesús María
# ...     ...     ...     ...                    ...
# 2464  32053      32     053  Villa González Ortega
# 2465  32054      32     054          Villa Hidalgo
# 2466  32055      32     055             Villanueva
# 2467  32056      32     056              Zacatecas
# 2468  32058      32     058  Santa María de la Paz
#
#                                                geometry
# 0     POLYGON ((2489072.503 1115771.584, 2489352.774...
# 1     POLYGON ((2494680.261 1141224.505, 2494749.948...
# 2     POLYGON ((2429607.454 1120262.254, 2429071.902...
# 3     POLYGON ((2470517.824 1155028.588, 2470552.248...
# 4     POLYGON ((2465526.729 1114740.466, 2465752.546...
# ...

# %%
test_l
# Out:
#           CVEGEO CVE_ENT CVE_MUN CVE_LOC  \
# 0      010060024      01     006    0024
# 1      010060045      01     006    0045
# 2      010060233      01     006    0233
# 3      010060258      01     006    0258
# 4      010060287      01     006    0287
# ...          ...     ...     ...     ...
# 50303  320570028      32     057    0028
# 50304  320570001      32     057    0001
# 50305  320580017      32     058    0017
# 50306  320580037      32     058    0037
# 50307  320580001      32     058    0001
#
#                                        NOMGEO  AMBITO  \
# 0                         Ojo Zarco [Colonia]   Rural
# 1                                    Santiago   Rural
# 2      San Carlos [Fraccionamiento Campestre]   Rural
# 3                                    El Canal   Rural
# 4                                  Las Flores   Rural
# ...                                       ...     ...
# 50303                     San José del Carmen   Rural
# ...

# %%
test_lpr
# Out:
#                   CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB CVE_MZA  \
# 0       0101002630092800      01     010    0263     0092     800
# 1       010030085005A800      01     003    0085     005A     800
# 2       0100500170035800      01     005    0017     0035     800
# 3       0100704600025800      01     007    0460     0025     800
# 4       010110012009A800      01     011    0012     009A     800
# ...                  ...     ...     ...     ...      ...     ...
# 295774  3205800390049800      32     058    0039     0049     800
# 295775  3205800400034800      32     058    0040     0034     800
# 295776  3205800410053800      32     058    0041     0053     800
# 295777  3205800420049800      32     058    0042     0049     800
# 295778  3205800430049800      32     058    0043     0049     800
#
#                        NOMGEO PLANO                         geometry
# 0        El Papalote [Rancho]    No  POINT (2489803.622 1095457.401)
# ...
